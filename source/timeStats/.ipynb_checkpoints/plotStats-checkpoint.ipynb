# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.set()
import numpy as np
import time
import timeit

# %%
df = pd.read_csv('stats.csv')

# %%
df.head()
# Out:
#     File name  Edges modified  Execution time
# 0  heur001.gr              13        0.001000
# 1  heur002.gr            1129        0.032980
# 2  heur003.gr            1708        0.018990
# 3  heur004.gr            2126        0.032981
# 4  heur005.gr            2944        0.025985

# %%
df.plot(subplots=True)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
x = df['File name']
y = df['Edges modified']
z = df['Execution time']

# %%
fig, ax1 = plt.subplots()

ax1.plot(x, y, lw=2, color="blue")
ax1.set_ylabel(r"Edges modified", fontsize=18, color="blue")
for label in ax1.get_yticklabels():
    label.set_color("blue")
    
ax2 = ax1.twinx()
ax2.plot(x, z, lw=2, color="red")
ax2.set_ylabel(r"Execution time $(s)$", fontsize=18, color="red")
for label in ax2.get_yticklabels():
    label.set_color("red")
